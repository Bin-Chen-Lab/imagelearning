# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Objective" data-toc-modified-id="Objective-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Objective</a></span><ul class="toc-item"><li><span><a href="#we-are-trying-to-classify-for-Breast-Cancer-PATH_M_COMBINED:" data-toc-modified-id="we-are-trying-to-classify-for-Breast-Cancer-PATH_M_COMBINED:-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>we are trying to classify for Breast Cancer PATH_M_COMBINED:</a></span></li><li><span><a href="#Loading-Pickle-And-CSV-Files-as-Dataframes" data-toc-modified-id="Loading-Pickle-And-CSV-Files-as-Dataframes-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Loading Pickle And CSV Files as Dataframes</a></span></li><li><span><a href="#Custom-Dataset-to-best-utilize-the-data" data-toc-modified-id="Custom-Dataset-to-best-utilize-the-data-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Custom Dataset to best utilize the data</a></span></li><li><span><a href="#The-Classifier-Structure" data-toc-modified-id="The-Classifier-Structure-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>The Classifier Structure</a></span></li><li><span><a href="#Training-Method" data-toc-modified-id="Training-Method-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Training Method</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Objective
# We want to use a Convolutional Neural Network to Classify different Cancer Statuses:
#
#  1. M0
#  1. M1
#
#
# ## we are trying to classify for Breast Cancer PATH_M_COMBINED:

# %%
#imports
import torch
import torch.nn as nn
from torch.utils.data import dataset, dataloader
from torch.autograd import Variable
import torch.nn.functional as F
import pandas as pd
import pickle
import os
import sys
from datetime import datetime

# %% [markdown]
# ## Loading Pickle And CSV Files as Dataframes

# %%
#training data
dftraintest = pickle.load(open('keithtest.pkl','rb'))
#validation data
dfval = pickle.load(open('keithval.pkl', 'rb'))
#csv
phenotable_known = pd.read_csv('keith_traintestset_phenotype_primary_M_known.csv')
phenotable_unknown = pd.read_csv('keith_valset_pheonotype_primary_M_unknown.csv')
labels = ['M0', 'M1']

# %%
phenotable_known
# Out:
#             sample.id sample.type              biopsy.site  \
# 0     TCGA-05-4244-01     primary                     LUNG
# 1     TCGA-05-4250-01     primary                     LUNG
# 2     TCGA-05-4382-01     primary                     LUNG
# 3     TCGA-05-4384-01     primary                     LUNG
# 4     TCGA-05-4389-01     primary                     LUNG
# 5     TCGA-05-4390-01     primary                     LUNG
# 6     TCGA-05-4395-01     primary                     LUNG
# 7     TCGA-05-4396-01     primary                     LUNG
# 8     TCGA-05-4397-01     primary                     LUNG
# 9     TCGA-05-4398-01     primary                     LUNG
# 10    TCGA-05-4402-01     primary                     LUNG
# 11    TCGA-05-4403-01     primary                     LUNG
# 12    TCGA-05-4405-01     primary                     LUNG
# 13    TCGA-05-4410-01     primary                     LUNG
# 14    TCGA-05-4415-01     primary                     LUNG
# 15    TCGA-05-4417-01     primary                     LUNG
# 16    TCGA-05-4418-01     primary                     LUNG
# 17    TCGA-05-4420-01     primary                     LUNG
# 18    TCGA-05-4422-01     primary                     LUNG
# 19    TCGA-05-4424-01     primary                     LUNG
# 20    TCGA-05-4425-01     primary                     LUNG
# 21    TCGA-05-4426-01     primary                     LUNG
# 22    TCGA-05-4427-01     primary                     LUNG
# 23    TCGA-05-4430-01     primary                     LUNG
# 24    TCGA-05-4432-01     primary                     LUNG
# 25    TCGA-05-4433-01     primary                     LUNG
# 26    TCGA-05-4434-01     primary                     LUNG
# 27    TCGA-05-5423-01     primary                     LUNG
# 28    TCGA-05-5425-01     primary                     LUNG
# 29    TCGA-05-5428-01     primary                     LUNG
# ...               ...         ...                      ...
# 4118  TCGA-ZF-AA4X-01     primary                  BLADDER
# 4119  TCGA-ZF-AA51-01     primary                  BLADDER
# 4120  TCGA-ZF-AA53-01     primary                  BLADDER
# 4121  TCGA-ZF-AA5H-01     primary                  BLADDER
# 4122  TCGA-ZF-AA5N-01     primary                  BLADDER
# 4123  TCGA-ZF-AA5P-01     primary                  BLADDER
# 4124  TCGA-ZH-A8Y1-01     primary                BILE DUCT
# 4125  TCGA-ZH-A8Y2-01     primary                BILE DUCT
# 4126  TCGA-ZH-A8Y4-01     primary                BILE DUCT
# 4127  TCGA-ZH-A8Y5-01     primary                BILE DUCT
# 4128  TCGA-ZH-A8Y6-01     primary                BILE DUCT
# 4129  TCGA-ZH-A8Y8-01     primary                BILE DUCT
# 4130  TCGA-ZJ-AAX4-01     primary                   CERVIX
# 4131  TCGA-ZJ-AAX8-01     primary                   CERVIX
# 4132  TCGA-ZJ-AAXB-01     primary                   CERVIX
# 4133  TCGA-ZJ-AAXD-01     primary                   CERVIX
# 4134  TCGA-ZJ-AAXF-01     primary                   CERVIX
# 4135  TCGA-ZJ-AAXI-01     primary                   CERVIX
# 4136  TCGA-ZJ-AAXN-01     primary                   CERVIX
# 4137  TCGA-ZJ-AAXT-01     primary                   CERVIX
# 4138  TCGA-ZJ-AAXU-01     primary                   CERVIX
# 4139  TCGA-ZJ-AB0H-01     primary                   CERVIX
# 4140  TCGA-ZM-AA05-01     primary                   TESTIS
# 4141  TCGA-ZM-AA06-01     primary                   TESTIS
# 4142  TCGA-ZM-AA0B-01     primary                   TESTIS
# 4143  TCGA-ZM-AA0D-01     primary                   TESTIS
# 4144  TCGA-ZM-AA0E-01     primary                   TESTIS
# 4145  TCGA-ZM-AA0F-01     primary                   TESTIS
# 4146  TCGA-ZM-AA0H-01     primary                   TESTIS
# 4147  TCGA-ZN-A9VO-01     primary  LINING OF BODY CAVITIES
#
#                               cancer data.source  gender  age read.count.file  \
# 0                Lung Adenocarcinoma        TCGA    Male  NaN      TOIL.RData
# 1                Lung Adenocarcinoma        TCGA  Female  NaN      TOIL.RData
# 2                Lung Adenocarcinoma        TCGA    Male  NaN      TOIL.RData
# 3                Lung Adenocarcinoma        TCGA    Male  NaN      TOIL.RData
# 4                Lung Adenocarcinoma        TCGA    Male  NaN      TOIL.RData
# 5                Lung Adenocarcinoma        TCGA  Female  NaN      TOIL.RData
# 6                Lung Adenocarcinoma        TCGA    Male  NaN      TOIL.RData
# 7                Lung Adenocarcinoma        TCGA    Male  NaN      TOIL.RData
# 8                Lung Adenocarcinoma        TCGA    Male  NaN      TOIL.RData
# 9                Lung Adenocarcinoma        TCGA  Female  NaN      TOIL.RData
# 10               Lung Adenocarcinoma        TCGA  Female  NaN      TOIL.RData
# 11               Lung Adenocarcinoma        TCGA    Male  NaN      TOIL.RData
# 12               Lung Adenocarcinoma        TCGA  Female  NaN      TOIL.RData
# 13               Lung Adenocarcinoma        TCGA    Male  NaN      TOIL.RData
# 14               Lung Adenocarcinoma        TCGA    Male  NaN      TOIL.RData
# 15               Lung Adenocarcinoma        TCGA  Female  NaN      TOIL.RData
# 16               Lung Adenocarcinoma        TCGA    Male  NaN      TOIL.RData
# 17               Lung Adenocarcinoma        TCGA    Male  NaN      TOIL.RData
# 18               Lung Adenocarcinoma        TCGA    Male  NaN      TOIL.RData
# 19               Lung Adenocarcinoma        TCGA    Male  NaN      TOIL.RData
# 20               Lung Adenocarcinoma        TCGA  Female  NaN      TOIL.RData
# 21               Lung Adenocarcinoma        TCGA    Male  NaN      TOIL.RData
# 22               Lung Adenocarcinoma        TCGA  Female  NaN      TOIL.RData
# 23               Lung Adenocarcinoma        TCGA  Female  NaN      TOIL.RData
# 24               Lung Adenocarcinoma        TCGA    Male  NaN      TOIL.RData
# 25               Lung Adenocarcinoma        TCGA    Male  NaN      TOIL.RData
# 26               Lung Adenocarcinoma        TCGA  Female  NaN      TOIL.RData
# 27               Lung Adenocarcinoma        TCGA    Male  NaN      TOIL.RData
# 28               Lung Adenocarcinoma        TCGA    Male  NaN      TOIL.RData
# 29               Lung Adenocarcinoma        TCGA    Male  NaN      TOIL.RData
# ...                              ...         ...     ...  ...             ...
# 4118    Bladder Urothelial Carcinoma        TCGA    Male  NaN      TOIL.RData
# 4119    Bladder Urothelial Carcinoma        TCGA  Female  NaN      TOIL.RData
# 4120    Bladder Urothelial Carcinoma        TCGA    Male  NaN      TOIL.RData
# 4121    Bladder Urothelial Carcinoma        TCGA  Female  NaN      TOIL.RData
# 4122    Bladder Urothelial Carcinoma        TCGA  Female  NaN      TOIL.RData
# 4123    Bladder Urothelial Carcinoma        TCGA    Male  NaN      TOIL.RData
# 4124              Cholangiocarcinoma        TCGA  Female  NaN      TOIL.RData
# 4125              Cholangiocarcinoma        TCGA  Female  NaN      TOIL.RData
# 4126              Cholangiocarcinoma        TCGA    Male  NaN      TOIL.RData
# 4127              Cholangiocarcinoma        TCGA    Male  NaN      TOIL.RData
# 4128              Cholangiocarcinoma        TCGA  Female  NaN      TOIL.RData
# 4129              Cholangiocarcinoma        TCGA    Male  NaN      TOIL.RData
# 4130  Cervical & Endocervical Cancer        TCGA  Female  NaN      TOIL.RData
# 4131  Cervical & Endocervical Cancer        TCGA  Female  NaN      TOIL.RData
# 4132  Cervical & Endocervical Cancer        TCGA  Female  NaN      TOIL.RData
# 4133  Cervical & Endocervical Cancer        TCGA  Female  NaN      TOIL.RData
# 4134  Cervical & Endocervical Cancer        TCGA  Female  NaN      TOIL.RData
# 4135  Cervical & Endocervical Cancer        TCGA  Female  NaN      TOIL.RData
# 4136  Cervical & Endocervical Cancer        TCGA  Female  NaN      TOIL.RData
# 4137  Cervical & Endocervical Cancer        TCGA  Female  NaN      TOIL.RData
# 4138  Cervical & Endocervical Cancer        TCGA  Female  NaN      TOIL.RData
# 4139  Cervical & Endocervical Cancer        TCGA  Female  NaN      TOIL.RData
# 4140      Testicular Germ Cell Tumor        TCGA    Male  NaN      TOIL.RData
# 4141      Testicular Germ Cell Tumor        TCGA    Male  NaN      TOIL.RData
# 4142      Testicular Germ Cell Tumor        TCGA    Male  NaN      TOIL.RData
# 4143      Testicular Germ Cell Tumor        TCGA    Male  NaN      TOIL.RData
# 4144      Testicular Germ Cell Tumor        TCGA    Male  NaN      TOIL.RData
# 4145      Testicular Germ Cell Tumor        TCGA    Male  NaN      TOIL.RData
# 4146      Testicular Germ Cell Tumor        TCGA    Male  NaN      TOIL.RData
# 4147                    Mesothelioma        TCGA    Male  NaN      TOIL.RData
#
#      PATH_T_STAGE PATH_N_STAGE PATH_M_STAGE       stage CANCER_TYPE_ACRONYM  \
# 0              T2           N2           M1    STAGE IV                LUAD
# 1              T3           N1           M0  STAGE IIIA                LUAD
# 2              T2           N0           M0    STAGE IB                LUAD
# 3              T2           N2           M0  STAGE IIIA                LUAD
# 4              T1           N0           M0    STAGE IA                LUAD
# 5              T2           N0           M0    STAGE IB                LUAD
# 6              T4           N2           M0  STAGE IIIB                LUAD
# 7              T4           N1           M0  STAGE IIIB                LUAD
# 8              T2           N1           M0   STAGE IIB                LUAD
# 9              T4           N3           M0  STAGE IIIB                LUAD
# 10             T2           NX           M1    STAGE IV                LUAD
# 11             T2           N0           M0    STAGE IB                LUAD
# 12             T2           N0           M0    STAGE IB                LUAD
# 13             T2           N0           M0    STAGE IB                LUAD
# 14             T4           N2           M0  STAGE IIIB                LUAD
# 15             T2           N0           M0    STAGE IB                LUAD
# 16             T3           N2           M0  STAGE IIIA                LUAD
# 17             T2           N0           M0    STAGE IB                LUAD
# 18             T2           N0           M0    STAGE IB                LUAD
# 19             T3           N0           M0   STAGE IIB                LUAD
# 20             T2           N0           M1    STAGE IV                LUAD
# 21             T2           N0           M0    STAGE IB                LUAD
# 22             T2           N1           M0   STAGE IIB                LUAD
# 23             T2           N0           M0    STAGE IB                LUAD
# 24             T2           N1           M0   STAGE IIB                LUAD
# 25             T2           N0           M0    STAGE IB                LUAD
# 26             T4           N1           M1    STAGE IV                LUAD
# 27             T2           N1           M0   STAGE IIB                LUAD
# 28            T2B           N1           M0   STAGE IIB                LUAD
# 29            T1B           N1           M0   STAGE IIA                LUAD
# ...           ...          ...          ...         ...                 ...
# 4118           T2           NX           M0    STAGE II                BLCA
# 4119           T2           NX           M0    STAGE II                BLCA
# 4120           T2           NX           M0    STAGE II                BLCA
# 4121          T3B           N2           M0    STAGE IV                BLCA
# 4122           T2           NX           M1    STAGE IV                BLCA
# 4123          T2B           N2           M0    STAGE IV                BLCA
# 4124           T3           N1           M0   STAGE IVA                CHOL
# 4125           T1           NX           M0     STAGE I                CHOL
# 4126           T1           N0           M0     STAGE I                CHOL
# 4127           T3           N1           M1   STAGE IVB                CHOL
# 4128           T1           N0           M0     STAGE I                CHOL
# 4129           T1           N0           M0     STAGE I                CHOL
# 4130           T2           N0           M0          na                CESC
# 4131          T3B           N1           M0          na                CESC
# 4132         T1B2           N0           M0          na                CESC
# 4133          T3B           N0           M0          na                CESC
# 4134          T2B           N0           M0          na                CESC
# 4135          T2B           NX           M0          na                CESC
# 4136         T1B2           N1           M0          na                CESC
# 4137          T3B           N1           M0          na                CESC
# 4138          T2B           N0           M0          na                CESC
# 4139          T3B           N1           M0          na                CESC
# 4140           T2           NX           M0   STAGE IIC                TGCT
# 4141           T2           NX           M0    STAGE IB                TGCT
# 4142           T1           NX           M0    STAGE IA                TGCT
# 4143           T1           NX           M0    STAGE IA                TGCT
# 4144           T1           NX           M0    STAGE IA                TGCT
# 4145           T1           NX           M0    STAGE IA                TGCT
# 4146           T3           NX           M0    STAGE IS                TGCT
# 4147           T4           N2           M1    STAGE IV                MESO
#
#      PATH_M_combined
# 0                 M1
# 1                 M0
# 2                 M0
# 3                 M0
# 4                 M0
# 5                 M0
# 6                 M0
# 7                 M0
# 8                 M0
# 9                 M0
# 10                M1
# 11                M0
# 12                M0
# 13                M0
# 14                M0
# 15                M0
# 16                M0
# 17                M0
# 18                M0
# 19                M0
# 20                M1
# 21                M0
# 22                M0
# 23                M0
# 24                M0
# 25                M0
# 26                M1
# 27                M0
# 28                M0
# 29                M0
# ...              ...
# 4118              M0
# 4119              M0
# 4120              M0
# 4121              M0
# 4122              M1
# 4123              M0
# 4124              M0
# 4125              M0
# 4126              M0
# 4127              M1
# 4128              M0
# 4129              M0
# 4130              M0
# 4131              M0
# 4132              M0
# 4133              M0
# 4134              M0
# 4135              M0
# 4136              M0
# 4137              M0
# 4138              M0
# 4139              M0
# 4140              M0
# 4141              M0
# 4142              M0
# 4143              M0
# 4144              M0
# 4145              M0
# 4146              M0
# 4147              M1
#
# [4148 rows x 14 columns]

# %% [markdown]
# ## Custom Dataset to best utilize the data

# %%
#reliance on Pandas
class BC_Dataset(torch.utils.data.Dataset):
    def __init__(self, pickleframe, phenotable_csv):
        self.traintest = pickleframe
        self.phenotabledf = pd.read_csv(phenotable_csv)
        
    def __len__(self):
        return len(self.traintest)
    
    def __getitem__(self, idx):
        labels = torch.tensor([0,1], dtype=torch.long) if self.phenotabledf['PATH_M_combined'][idx] == 'M1' else torch.tensor([1,0], dtype=torch.long)
        return [labels, torch.tensor(dftraintest.loc[self.phenotabledf['sample.id'][idx], 'ENSG00000000003':'ENSGR0000281849'].values).float()]

# %% [markdown]
# ## The Classifier Structure

# %%
#A convolutional neural network for this classification
class BC_Classifier(nn.Module):
    def __init__(self):
        super(BC_Classifier, self).__init__()
        self.num_classes = len(labels)
        self.hidden_layer = torch.nn.Sequential(
                        torch.nn.Linear(60498, 1000),
                        torch.nn.ReLU(0.2, inplace=True),
                        torch.nn.Linear(1000, 200),
                        torch.nn.ReLU(0.2,inplace=True),
                        torch.nn.Linear(200,10),
                        torch.nn.ReLU(0.2,inplace=True),
                        torch.nn.Linear(10, self.num_classes),
                        torch.nn.Sigmoid()
                        )
    
    def forward(self, x):
        x = self.hidden_layer(x)
        return x

# %% [markdown]
# ## Training Method

# %%
### HYPER PARAMETERS ###
opt = pd.DataFrame()
opt.batch_size = 32
opt.cuda = True if torch.cuda.is_available() else False
opt.lr = 0.1
opt.beta1 = .5
opt.epochs = 50
opt.n_genes = 60498
opt.log_interval = 1




#loading data 
train_set = BC_Dataset(pickleframe=dftraintest,phenotable_csv='keith_traintestset_phenotype_primary_M_known.csv')
#wrapping this in a dataloader
train_loader = torch.utils.data.DataLoader(train_set, shuffle=True, batch_size= opt.batch_size)

val_set = BC_Dataset(dfval, phenotable_csv='keith_valset_pheonotype_primary_M_unknown.csv')
val_loader = torch.utils.data.DataLoader(val_set, shuffle = False, batch_size=4)

y = Variable(torch.Tensor(2).random_(1), requires_grad = True)
if opt.cuda:
    model = BC_Classifier().cuda()
    #still trying to get the loss working
    criterion = nn.BCEWithLogitsLoss().cuda()
    train_tensor = torch.FloatTensor(opt.batch_size, opt.n_genes).cuda()
else:
    model = BC_Classifier()
    criterion = torch.nn.CrossEntropyLoss()
    train_tensor = torch.FloatTensor(opt.batch_size, opt.n_genes)
    
optimizer = torch.optim.Adam(model.parameters(), lr=opt.lr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-171c6ee88769> in <module>()
#       1 ### HYPER PARAMETERS ###
# ----> 2 opt = pd.DataFrame()
#       3 opt.batch_size = 32
#       4 opt.cuda = True if torch.cuda.is_available() else False
#       5 opt.lr = 0.1
#
# NameError: name 'pd' is not defined

# %%
dataiter = iter(train_loader)

# %%
def train(model = model, optimizer = optimizer, epochs = opt.epochs):
    for epoch in range(opt.epochs + 1):
        train_epoch(epoch,  model, train_loader, optimizer)
        #test_epoch(model, val_loader)
        
#def mse_loss(input, target):
 #   return torch.sum((input - target)^2) / input.data.nelement()

def train_epoch(epoch, model, data_loader, optimizer):
    model.train()
    pid = os.getpid()
    for batch_idx, (target, data) in enumerate(data_loader):
        running_loss = 0.0
        optimizer.zero_grad()
        if opt.cuda:
            data, target = Variable(data.cuda()), Variable(target.cuda())
        output = model(data)
#        print(output)
#        print (torch.max(target,1)[1])
        loss = criterion(output, target.float())
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        if batch_idx % opt.log_interval == 0:
            #copied printing from AE training method
            print('%s-[%03d/%03d][%04d/%04d]--loss: %6.4f' % (
                datetime.now(), epoch, opt.epochs, batch_idx, len(data_loader), loss.item()))
            sys.stdout.flush()

            
'''
def test_epoch(model, data_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in data_loader:
            output = model(data)
            test_loss += F.nll_loss(output[1], target, reduction='sum').item() # sum up batch loss
            pred = output.max(1)[1] # get the index of the max log-probability
            correct += pred.eq(target).sum().item()

    test_loss /= len(data_loader.dataset)
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(data_loader.dataset),
        100. * correct / len(data_loader.dataset)))
'''


print('loaded model')
# Out:
# loaded model

# %%
train(model, optimizer, epochs=10)
# Out:
# 2018-08-17 20:01:27.782047-[000/050][0000/0130]--loss: 0.5188
# 2018-08-17 20:01:28.484899-[000/050][0010/0130]--loss: 0.5032
# 2018-08-17 20:01:29.149092-[000/050][0020/0130]--loss: 0.5032
# 2018-08-17 20:01:29.810676-[000/050][0030/0130]--loss: 0.5813
# 2018-08-17 20:01:30.472823-[000/050][0040/0130]--loss: 0.5345
# 2018-08-17 20:01:31.134092-[000/050][0050/0130]--loss: 0.5188
# 2018-08-17 20:01:31.795836-[000/050][0060/0130]--loss: 0.5188
# 2018-08-17 20:01:32.457260-[000/050][0070/0130]--loss: 0.5345
# 2018-08-17 20:01:33.119405-[000/050][0080/0130]--loss: 0.5501
# 2018-08-17 20:01:33.781098-[000/050][0090/0130]--loss: 0.5345
# 2018-08-17 20:01:34.443133-[000/050][0100/0130]--loss: 0.5345
# 2018-08-17 20:01:35.105207-[000/050][0110/0130]--loss: 0.5345
# 2018-08-17 20:01:35.767005-[000/050][0120/0130]--loss: 0.5188
# 2018-08-17 20:01:36.422657-[001/050][0000/0130]--loss: 0.5188
# 2018-08-17 20:01:37.084453-[001/050][0010/0130]--loss: 0.5501
# 2018-08-17 20:01:37.746129-[001/050][0020/0130]--loss: 0.5032
# 2018-08-17 20:01:38.407768-[001/050][0030/0130]--loss: 0.5188
# 2018-08-17 20:01:39.069551-[001/050][0040/0130]--loss: 0.5188
# 2018-08-17 20:01:39.730992-[001/050][0050/0130]--loss: 0.5032
# 2018-08-17 20:01:40.392236-[001/050][0060/0130]--loss: 0.5188
# 2018-08-17 20:01:41.054439-[001/050][0070/0130]--loss: 0.5345
# 2018-08-17 20:01:41.716090-[001/050][0080/0130]--loss: 0.5188
# 2018-08-17 20:01:42.377251-[001/050][0090/0130]--loss: 0.5970
# 2018-08-17 20:01:43.039695-[001/050][0100/0130]--loss: 0.5188
# 2018-08-17 20:01:43.700906-[001/050][0110/0130]--loss: 0.5501
# 2018-08-17 20:01:44.362334-[001/050][0120/0130]--loss: 0.5501
# 2018-08-17 20:01:45.018610-[002/050][0000/0130]--loss: 0.5501
